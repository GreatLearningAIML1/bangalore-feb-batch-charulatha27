# %% [markdown]
# ## Lab 2

# %% [markdown]
# Welcome to the second lab of the AIML!
# In addition to implementing code, there will be questions that you must answer which relate to the lab and your implementation. Each question you will answer is preceded by a **'Question X'** header. Carefully read each question and provide you answer or code in the following textboxes with **'Answer:'** header. Your lab submission will be evaluated based on your answers to each of the questions and the implementation you provide.

# %% [markdown]
# # Every question is of 1 mark.

# %% [markdown]
# ## Overview

# %% [markdown]
# This module covers,
#
# 1) One sample and Two sample t-tests
#
# 2) ANOVA
#
# 3) Type I and Type II errors
#
# 4) Probabilty Distributions
#
# 5) Linear Regression

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# The purpose of the test is to tell if there is any significant difference between two data sets.

# %% [markdown]
# ## Question 1
#
# *A student is trying to decide between two GPUs. He want to use the GPU for his research to run Deep learning algorithms, so the only thing he is concerned with is speed.*
#
# *He picks a Deep Learning algorithm on a large data set and runs it on both GPUs 15 times, timing each run in hours. Results are given in the below lists GPU1 and GPU2.*

# %% [markdown]
# Hint: You can import ttest function from scipy to perform t tests

# %% [markdown]
# Given,
#
# Null Hypothesis : There is no significant difference between data sets
#
# Alternate Hypothesis : There is a significant difference
#
# *Do two-sample testing and check whether to reject Null Hypothesis or not.*
#
# #### Answer:

# %%
import pandas as pd
from scipy.stats import ttest_ind, shapiro
GPU1 = pd.DataFrame([11,9,10,11,10,12,9,11,12,9,11,12,9,10,9])
GPU2 = pd.DataFrame([11,13,10,13,12,9,11,12,12,11,12,12,10,11,13])

# %%
shapiro(GPU1)
# Out:
# (0.8538349270820618, 0.019687309861183167)

# %%
shapiro(GPU2)
# Out:
# (0.9172669053077698, 0.17497925460338593)

# %%
#### Answer:

# %%
t_statistic, p_value = ttest_ind(GPU1, GPU2)
print(t_statistic, p_value)
print('\nAnswer: P_value < 0.05 and hence GPU1 and GPU2 are significantly different')
print('\nAnswer: Null hypothesis is rejected because GPU1 and GPU1 pvalue from ttest_ind is less than 0.05')
# Out:
# [-2.62762951] [0.01379428]
#
# Answer: P_value < 0.05 and hence GPU1 and GPU2 are significantly different
#
# Answer: Null hypothesis is rejected because GPU1 and GPU1 pvalue from ttest_ind is less than 0.05

# %% [markdown]
# [## Question 2
# ](https://)
# He is trying a third GPU which is GPU3.

# %%
GPU3 = pd.DataFrame([9,10,9,11,10,13,12,9,12,12,13,12,13,10,11])

#Assumption: Both the datasets (GPU1 & GPU 3) are random, independent, parametric & normally distributed

# %% [markdown]
# *Do two-sample testing and check whether there is significant differene between speeds of two GPUs GPU1 and GPU3.*
#
# #### Answer:

# %%
#Null Hypothesis : There is no significant difference between data sets
#Alternate Hypothesis : There is a significant difference
    
#compare GPU1 and GPU3 
t_statistic, p_value = ttest_ind(GPU1, GPU3)
print(t_statistic, p_value)
print('Answer: P_value > 0.05 and hence GPU1 and GPU3 do not have significant difference')
print('Answer: Null hypothesis is accepted because GPU1 and GPU3 pvalue from ttest_ind > 0.05')
# Out:
# [-1.49889438] [0.14509211]
# Answer: P_value > 0.05 and hence GPU1 and GPU3 do not have significant difference
# Answer: Null hypothesis is accepted because GPU1 and GPU3 pvalue from ttest_ind > 0.05

# %% [markdown]
# ### ANOVA

# %% [markdown]
# ## Question 3
#
# If you need to compare more than two data sets at a time, an ANOVA is your best bet.
#
# *The results from three experiments with overlapping 95% confidence intervals are given below, and we want to confirm that the results for all three experiments are not significantly different.*
#
# #Assumption: All the 3 datasets (e1,e2 & e3) are random, independent, parametric & normally distributed
# But before conducting ANOVA, test equality of variances (using Levene's test) is satisfied or not. If not, then mention that we cannot depend on the result of ANOVA

# %%
import pandas as pd
e1 = pd.DataFrame([1.595440,1.419730,0.000000,0.000000])
e2 = pd.DataFrame([1.433800,2.079700,0.892139,2.384740])
e3 = pd.DataFrame([0.036930,0.938018,0.995956,1.006970])

# %%
from scipy.stats import levene, f_oneway
from statsmodels.stats.anova import anova_lm

# %%
# Levene's Test

# H0: All variances are equal
# Ha: Atleast one of the variances not equal

print(levene(e1,e2,e3))
print('Answer: ')
print('All variances are equal')
print('p-value > 0.05 hence all variances are equal. Hence we can rely on ANOVA test')
# Out:
# LeveneResult(statistic=array([2.67417257]), pvalue=array([0.12259793]))
# Answer:
# All variances are equal
# p-value > 0.05 hence all variances are equal. Hence we can rely on ANOVA test

# %%
f, p = f_oneway(e1,e2,e3)
print ('One-way ANOVA')
print ('=============')
 
print ('F value:', f)
print ('P value:', p, '\n')
print('Since p-value > 0.05 , we say that all means are equal')
# Out:
# One-way ANOVA
# ...
# F value: [2.51357623]
# P value: [0.13574645]
#
# Since p-value > 0.05 , we say that all means are equal

# %% [markdown]
# Hint - You can use stats.levene function and stats.f_oneway function.

# %% [markdown]
# #### Answer:

# %%
print('Answer')
print('From levene test all variances are equal. Hence we can rely on ANOVA test')
print('All means are equal')
print('Null Hypothesis: Means are equal across all groups')
print('Null Hypothesis is accepted')
# Out:
# Answer
# From levene test all variances are equal. Hence we can rely on ANOVA test
# All means are equal
# Null Hypothesis: Means are equal across all groups
# Null Hypothesis is accepted

# %% [markdown]
# ## Question 4
#
# *In one or two sentences explain about **TypeI** and **TypeII** errors.*
#
# #### Answer:

# %%
print('A type I error is the rejection of a true null hypothesis')
print('Type I error: When the null hypothesis is true and it is rejected, it is a type I error')
print()
print('A type II error is the failure to reject a false null hypothesis')
print('Type II error: When the null hypothesis is false and it is not rejected, it is a type II error')
# Out:
# A type I error is the rejection of a true null hypothesis
# Type I error: When the null hypothesis is true and it is rejected, it is a type I error
#
# A type II error is the failure to reject a false null hypothesis
# Type II error: When the null hypothesis is false and it is not rejected, it is a type II error

# %% [markdown]
# # Question 5
#
# You are a manager of a chinese restaurant. You want to determine whether the waiting time to place an order has changed in the past month from its previous population mean value of 4.5 minutes.
# State the null and alternative hypothesis.

# %%
print('H0  Null Hypothesis: The population mean is the same (Waiting time mean value of 4.5 minutes is the same in the past month)')
print()
print('H0 : Population Mean of Waiting time is 4.5 minutes in the past month')
# Out:
# H0  Null Hypothesis: The population mean is the same (Waiting time mean value of 4.5 minutes is the same in the past month)
#
# H0 : Population Mean of Waiting time is 4.5 minutes in the past month

# %%
print('Ha  Alternative Hypothesis: The population mean has significantly changed (Waiting time mean value of 4.5 minutes is significantly different in the past month)')
print()
print('Ha : Population Mean of Waiting time is not 4.5 minutes in the past month')
# Out:
# Ha  Alternative Hypothesis: The population mean has significantly changed (Waiting time mean value of 4.5 minutes is significantly different in the past month)
#
# Ha : Population Mean of Waiting time is not 4.5 minutes in the past month

# %% [markdown]
# # Question 6
# Get the binomial distribution with n = 10, p = .7 and k = [0, 1, 2, 3, 4, 5, 6, 7]
#
# Hint - Use stats.binom.pmf() function for this.

# %%
import scipy.stats as stats
n = 10
p = .7
k = [0, 1, 2, 3, 4, 5, 6, 7]

binomial = stats.binom.pmf(k,n,p)
binomial
# Out:
# array([5.90490000e-06, 1.37781000e-04, 1.44670050e-03, 9.00169200e-03,
#        3.67569090e-02, 1.02919345e-01, 2.00120949e-01, 2.66827932e-01])

# %% [markdown]
# # Question 7
# Plot the distribution created in the above question.

# %%
import matplotlib.pyplot as plt
plt.plot(k,binomial,'o-')
plt.title('Binomial: n=%i , p=%.2f' % (n,p), fontsize=15)
plt.show()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Here we will try to see that if we can make a regression model to predict one column of a dataset by the use of other coloumn.
#
# ## Dataset
#
# Population of U.S. Cities
#
# ### Description
# The bigcity data frame has 49 rows and 2 columns.
#
# The measurements are the population (in 1000's) of 49 U.S. cities in 1920 and 1930. The 49 cities are a random sample taken from the 196 largest cities in 1920.
#
# ### Format
# This data frame contains the following columns:
#
# `u`
# The 1920 population.
#
# `x`
# The 1930 population.
#
# There is one unnamed column also in this dataset. Please remove and ignore that coloumn.
#
# Source
#
# The data were obtained from
#
# Cochran, W.G. (1977) Sampling Techniques. Third edition. John Wiley
#
# References
#
# Davison, A.C. and Hinkley, D.V. (1997) Bootstrap Methods and Their Application. Cambridge University Press.

# %% [markdown]
# # Question 8
# Read the dataset given in file named 'bigcity.csv'.

# %%
import pandas as pd
city = pd.read_csv("bigcity.csv", index_col=0)
#already the unknown column is removed while reading csv
city.head()
# Out:
#      u    x
# 1  138  143
# 2   93  104
# 3   61   69
# 4  179  260
# 5   48   75

# %% [markdown]
# # Question 9 - Transform the dataset
# Find the number of rows in given dataset and separate the input(u column)  and target variables(x column) into X and Y.
#
# Remove the unnamed coloumn.
#
# Hint: You can shape function to get the size of the dataframe

# %%
city = pd.read_csv("bigcity.csv")
city = city.drop(columns=['Unnamed: 0'])
city.head()
# Out:
#      u    x
# 0  138  143
# 1   93  104
# 2   61   69
# 3  179  260
# 4   48   75

# %%
city.shape
# Out:
# (49, 2)

# %%
X = city['u'].values.reshape(-1,1)
X
# Out:
# array([[138],
#        [ 93],
#        [ 61],
#        [179],
#        [ 48],
#        [ 37],
#        [ 29],
#        [ 23],
#        [ 30],
#        [  2],
#        [ 38],
#        [ 46],
#        [ 71],
#        [ 25],
#        [298],
#        [ 74],
#        [ 50],
#        [ 76],
#        [381],
#        [387],
#        [ 78],
#        [ 60],
#        [507],
#        [ 50],
#        [ 77],
#        [ 64],
#        [ 40],
#        [136],
#        [243],
#        [256],
#        [ 94],
#        [ 36],
#        [ 45],
#        [ 67],
#        [120],
#        [172],
#        [ 66],
#        [ 46],
#        [121],
#        [ 44],
#        [ 64],
#        [ 56],
#        [ 40],
#        [116],
#        [ 87],
#        [ 43],
#        [ 43],
#        [161],
#        [ 36]], dtype=int64)

# %%
Y = city['x'].values.reshape(-1,1)
Y
# Out:
# array([[143],
#        [104],
#        [ 69],
#        [260],
#        [ 75],
#        [ 63],
#        [ 50],
#        [ 48],
#        [111],
#        [ 50],
#        [ 52],
#        [ 53],
#        [ 79],
#        [ 57],
#        [317],
#        [ 93],
#        [ 58],
#        [ 80],
#        [464],
#        [459],
#        [106],
#        [ 57],
#        [634],
#        [ 64],
#        [ 89],
#        [ 77],
#        [ 60],
#        [139],
#        [291],
#        [288],
#        [ 85],
#        [ 46],
#        [ 53],
#        [ 67],
#        [115],
#        [183],
#        [ 86],
#        [ 65],
#        [113],
#        [ 58],
#        [ 63],
#        [142],
#        [ 64],
#        [130],
#        [105],
#        [ 61],
#        [ 50],
#        [232],
#        [ 54]], dtype=int64)

# %% [markdown]
# ## Question 10 - Check the dataset for any missing values and also print out the correlation matrix

# %%
city.isna()
# Out:
#         u      x
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False
# 26  False  False
# 27  False  False
# 28  False  False
# 29  False  False
# 30  False  False
# 31  False  False
# 32  False  False
# 33  False  False
# 34  False  False
# 35  False  False
# 36  False  False
# 37  False  False
# 38  False  False
# 39  False  False
# 40  False  False
# 41  False  False
# 42  False  False
# 43  False  False
# 44  False  False
# 45  False  False
# 46  False  False
# 47  False  False
# 48  False  False

# %%
city.corr()
# Out:
#           u         x
# u  1.000000  0.981742
# x  0.981742  1.000000

# %% [markdown]
# You can use .isna() and .corr() functions to check NA's and correlation in the dataframe respectively

# %%
print('Answer:')
print('The dataset does not have any missing data')
# Out:
# Answer:
# The dataset does not have any missing data

# %%
print('Answer:')
print('x and u are correlated by a coefficient of 0.98 indicating highly positive correlation association')
# Out:
# Answer:
# x and u are correlated by a coefficient of 0.98 indicating highly positive correlation association

# %% [markdown]
# ### The high correlation betwwen u and x indicates that the variable u is a good predictor of variable x

# %% [markdown]
# # Question 11 - Split data into train, test sets
# Divide the data into training and test sets with 80-20 split using scikit-learn. Print the shapes of training and test feature sets.*

# %% [markdown]
# Check: train_test_split function

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print('X Training Set:\n\n',X_train)
print('\n\nX Test Set:\n', X_test)
print('\n\nY Training Set:\n', Y_train)
print('\n\nY Test Set:\n\n', Y_test)
# Out:
# X Training Set:
#
#  [[ 46]
#  [ 36]
#  [ 67]
#  [136]
#  [ 36]
#  [ 61]
#  [ 43]
#  [381]
#  [ 74]
#  [243]
#  [507]
#  [ 50]
#  [ 56]
#  [ 78]
#  [ 40]
#  [ 30]
#  [ 25]
#  [ 64]
#  [ 37]
#  [ 76]
#  [172]
#  [298]
#  [121]
#  [ 93]
#  [ 71]
#  [116]
#  [ 77]
#  [ 29]
#  [ 50]
#  [ 66]
#  [ 60]
#  [387]
#  [  2]
#  [ 44]
#  [ 43]
#  [179]
#  [138]
#  [161]
#  [ 87]]
#
#
# X Test Set:
#  [[256]
#  [ 48]
#  [ 40]
#  [ 94]
#  [ 45]
#  [ 46]
#  [120]
#  [ 64]
#  [ 23]
#  [ 38]]
#
#
# Y Training Set:
#  [[ 53]
#  [ 46]
#  [ 67]
#  [139]
#  [ 54]
#  [ 69]
#  [ 50]
#  [464]
#  [ 93]
#  [291]
#  [634]
#  [ 58]
#  [142]
#  [106]
#  [ 64]
#  [111]
#  [ 57]
#  [ 77]
#  [ 63]
#  [ 80]
#  [183]
#  [317]
#  [113]
#  [104]
#  [ 79]
#  [130]
#  [ 89]
#  [ 50]
#  [ 64]
#  [ 86]
#  [ 57]
#  [459]
#  [ 50]
#  [ 58]
#  [ 61]
#  [260]
#  [143]
#  [232]
#  [105]]
#
#
# Y Test Set:
#
#  [[288]
#  [ 75]
#  [ 60]
#  [ 85]
#  [ 53]
#  [ 65]
#  [115]
#  [ 63]
#  [ 48]
#  [ 52]]

# %%
X_train.shape
# Out:
# (39, 1)

# %%
Y_train.shape
# Out:
# (39, 1)

# %%
X_test.shape
# Out:
# (10, 1)

# %%
Y_test.shape
# Out:
# (10, 1)

# %% [markdown]
# # Question 12 - Find coefficients & intercept
# Estimate the coefficients b0 and b1 using scikit-learn.

# %%
from sklearn.linear_model import LinearRegression

# Create linear regression object
regr = LinearRegression()

# %%
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
b0 = regr.coef_
b0
# Out:
# array([[1.16465537]])

# %%
b1=regr.intercept_
b1
# Out:
# array([9.57115437])

# %% [markdown]
# Check: coef_ and intercept_ functions can help you get coefficients & intercept

# %% [markdown]
# # Question 13 - Linear Relationship between feature and target
# Plot the line with b1 and b0 as slope and y-intercept.
#
# Hint - y = mx + c, plot y

# %%
import seaborn as sns
sns.lmplot(x ="x", 
           y = "u", data = city)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Y_ = b0*X_train + b1
plt.plot(X_train, Y_, '-r', label='y=b0*x+b1')
plt.title('Graph of y=b0*x+b1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
Y_ = b0*X_test + b1
plt.plot(X_test, Y_, '-r', label='y=b0*x+b1')
plt.title('Graph of y=b0*x+b1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# # Question 14 - Evaluation of model with scikit-learn
# Validate the model with Root Mean Squares error and R^2 score using scikit-learn. RMSE and R2 for test data and prediction

# %% [markdown]
# Hint: You can import mean_squared_error function & r2 (R square) from sklearn.metrics. Performing root operation over mean square error over mean square error gives you root mean square error

# %%
#y_pred = lm.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
Y_pred= regr.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)

rmse = sqrt(mse)
rmse
# Out:
# 18.71070389373071

# %%
# Explained variance score: 1 is perfect prediction
r2_score(Y_test, Y_pred)
# Out:
# 0.92536721776934

# %% [markdown]
# ## Question 15 - Calculate the accuracy of the model for both training and test data set

# %% [markdown]
# ### Hint: .score() function

# %%
regr.score(X_train, Y_train)
# Out:
# 0.9652735334606501

# %%
regr.score(X_test, Y_test)
# Out:
# 0.92536721776934
