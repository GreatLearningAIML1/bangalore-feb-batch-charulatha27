# %% [markdown]
# # Transfer Learning MNIST

# %% [markdown]
# * Train a simple convnet on the MNIST dataset the first 5 digits [0-4].
# * Freeze convolutional layers and fine-tune dense layers for the classification of digits [5-9].

# %% [markdown]
# ## MNIST Dataset
# The MNIST database contains 60,000 training images and 10,000 testing images taken from American Census Bureau employees and American high school students. The MNIST dataset is one of the most common datasets used for image classification and accessible from many different sources. In fact, even Tensorflow and Keras allow us to import and download the MNIST dataset directly from their API.

# %% [markdown]
# Let's import keras and load MNIST dataset

# %%
# Initialize the random number generator
import random
random.seed(0)

import warnings
warnings.filterwarnings("ignore")

# %%
from keras.backend import backend
from keras.datasets import mnist

# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# X_train and X_test contain greyscale RGB codes (from 0 to 255) while y_train and y_test contains labels from 0 to 9 which represents which number they actually are.

# %% [markdown]
# Let's visualize some numbers using matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
print("Label: {}".format(y_train[1000]))
plt.imshow(X_train[1000], cmap='gray')
# Out:
# Label: 0

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Create two datasets
# - First having digits from 0 to 4
# - Second having digits from 5 to 9
#
# Hint: use labels to separate data

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
import numpy as np

train_filter_0_4 = np.where(y_train <= 4 )
test_filter_0_4 = np.where(y_test <= 4 )

train_filter_5_9 = np.where(y_train >= 5 )
test_filter_5_9 = np.where(y_test >= 5 )


X_train_0_4, Y_train_0_4 = X_train[train_filter_0_4], y_train[train_filter_0_4]
X_test_0_4, Y_test_0_4 = X_test[test_filter_0_4], y_test[test_filter_0_4]


X_train_5_9, Y_train_5_9 = X_train[train_filter_5_9], y_train[train_filter_5_9]
X_test_5_9, Y_test_5_9 = X_test[test_filter_5_9], y_test[test_filter_5_9]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Print shape of the data
# - print shape of all variables of both the datasets you created

# %%
print('X_train_0_4:', X_train_0_4.shape)
print('Y_train_0_4:', Y_train_0_4.shape)
print('X_test_0_4:', X_test_0_4.shape)
print('Y_test_0_4:', Y_test_0_4.shape)
print('X_train_5_9:', X_train_5_9.shape)
print('Y_train_5_9:', Y_train_5_9.shape)
print('X_test_5_9:', X_test_5_9.shape)
print('Y_test_5_9:', Y_test_5_9.shape)
# Out:
# X_train_0_4: (30596, 28, 28)
# Y_train_0_4: (30596,)
# X_test_0_4: (5139, 28, 28)
# Y_test_0_4: (5139,)
# X_train_5_9: (29404, 28, 28)
# Y_train_5_9: (29404,)
# X_test_5_9: (4861, 28, 28)
# Y_test_5_9: (4861,)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Reshape data
# - reshape first dataset
# - To be able to use the dataset in Keras, we need 4-dims numpy arrays.
# - reshape features to pass it to a Conv2D layer
# - channel = 1
# - reshape features of first dataset only
# - do not reshape labels

# %%
# Reshaping the array to 4-dims so that it can work with the Keras API
xtrain4 = X_train_0_4.reshape(X_train_0_4.shape[0], 28, 28, 1)
xtest4 = X_test_0_4.reshape(X_test_0_4.shape[0], 28, 28, 1)

#use similar variable names for both datasets
xtrain9 = X_train_5_9
xtest9 = X_test_5_9

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Normalize data
# - normalize first dataset
# - we must normalize our data as it is always required in neural network models
# - we can achieve this by dividing the RGB codes to 255 (which is the maximum RGB code minus the minimum RGB code)
# - normalize X_train and X_test
# - make sure that the values are float so that we can get decimal points after division

# %%
# Making sure that the values are float so that we can get decimal points after division
xtrain4 = xtrain4.astype('float32')
xtest4 = xtest4.astype('float32')
# Normalizing the RGB codes by dividing it to the max RGB value.
xtrain4 /= 255
xtest4 /= 255

# %% [markdown]
# ### Print shape of data and number of images
# - for first dataset
# - print shape of X_train
# - print number of images in X_train
# - print number of images in X_test

# %%
print('xtrain4:', xtrain4.shape)
print(' No of train images in dataset1:', Y_train_0_4.shape)
print('xtest4:', xtest4.shape)
print('No of test images in dataset1:', Y_test_0_4.shape)
print('xtrain9:', xtrain9.shape)
print('No of train images in dataset2:', Y_train_5_9.shape)
print('xtest9:', xtest9.shape)
print('No of test images in dataset2:', Y_test_5_9.shape)
# Out:
# xtrain4: (30596, 28, 28, 1)
#  No of train images in dataset1: (30596,)
# xtest4: (5139, 28, 28, 1)
# No of test images in dataset1: (5139,)
# xtrain9: (29404, 28, 28)
# No of train images in dataset2: (29404,)
# xtest9: (4861, 28, 28)
# No of test images in dataset2: (4861,)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### One-hot encode the class vector
# - encode labels of first dataset
# - convert class vectors (integers) to binary class matrix
# - convert y_train and y_test
# - number of classes: 5
# - we are doing this to use categorical_crossentropy as loss
#
# Hint: you can use keras.utils.to_categorical

# %%
import keras
num_classes = 5
ytrain4 = keras.utils.to_categorical(Y_train_0_4, num_classes)
ytest4 = keras.utils.to_categorical(Y_test_0_4, num_classes)

#use similar variable names for both datasets
ytrain9 = Y_train_5_9
ytest9 = Y_test_5_9

# %%
print('xtrain4:', xtrain4.shape)
print('ytrain4:', ytrain4.shape)
print('xtest4:', xtest4.shape)
print('ytest4:', ytest4.shape)
print('xtrain9:', xtrain9.shape)
print('ytrain9:', ytrain9.shape)
print('xtest9:', xtest9.shape)
print('ytest9:', ytest9.shape)
# Out:
# xtrain4: (30596, 28, 28, 1)
# ytrain4: (30596, 5)
# xtest4: (5139, 28, 28, 1)
# ytest4: (5139, 5)
# xtrain9: (29404, 28, 28)
# ytrain9: (29404,)
# xtest9: (4861, 28, 28)
# ytest9: (4861,)

# %% [markdown]
# ## Question 6
# We will build our model by using high level Keras.

# %% [markdown]
# ### Initialize a sequential model
# - define a sequential model
# - add 2 convolutional layers
#     - no of filters: 32
#     - kernel size: 3x3
#     - activation: "relu"
#     - input shape: (28, 28, 1) for first layer
# - add a max pooling layer of size 2x2
# - add a dropout layer
#     - dropout layers fight with the overfitting by disregarding some of the neurons while training
#     - use dropout rate 0.2

# %%
# Importing the required Keras modules containing model and layers
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

num_classes = 5 

model = Sequential()

# The input layer requires the special input_shape parameter which should match
# the shape of our training data.
model.add(Conv2D(32, 3, 3, activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 32)        0
# =================================================================
# Total params: 9,568
# Trainable params: 9,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Add classification layers
# - do this after doing question 6
# - flatten the data
#     - add Flatten later
#     - flatten layers flatten 2D arrays to 1D array before building the fully connected layers
# - add 2 dense layers
#     - number of neurons in first layer: 128
#     - number of neurons in last layer: number of classes
#     - activation function in first layer: relu
#     - activation function in last layer: softmax
#     - we may experiment with any number of neurons for the first Dense layer; however, the final Dense layer must have neurons equal to the number of output classes
# - you can add a dropout layer in between, if necessary

# %%
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               589952
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 600,165
# Trainable params: 600,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Compile and fit the model
# - compile your model
#     - loss: "categorical_crossentropy"
#     - metrics: "accuracy"
#     - optimizer: "sgd"
# - fit your model
#     - give train data - features and labels
#     - batch size: 128
#     - epochs: 10
#     - give validation data - features and labels

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
model.fit(xtrain4, ytrain4, 
          batch_size=128, nb_epoch=10, verbose=1, validation_data=(xtest4, ytest4))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 30596 samples, validate on 5139 samples
# Epoch 1/10
# 30596/30596 [==============================] - 5s 148us/step - loss: 0.5767 - acc: 0.8163 - val_loss: 0.2364 - val_acc: 0.9274
# Epoch 2/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1925 - acc: 0.9410 - val_loss: 0.1135 - val_acc: 0.9642
# Epoch 3/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1568 - acc: 0.9519 - val_loss: 0.0735 - val_acc: 0.9774
# Epoch 4/10
# 30596/30596 [==============================] - 2s 53us/step - loss: 0.1358 - acc: 0.9582 - val_loss: 0.0668 - val_acc: 0.9805
# Epoch 5/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1249 - acc: 0.9625 - val_loss: 0.0597 - val_acc: 0.9813
# Epoch 6/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1162 - acc: 0.9649 - val_loss: 0.0518 - val_acc: 0.9840
# Epoch 7/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1069 - acc: 0.9681 - val_loss: 0.0468 - val_acc: 0.9852
# Epoch 8/10
# 30596/30596 [==============================] - 2s 55us/step - loss: 0.1050 - acc: 0.9680 - val_loss: 0.0464 - val_acc: 0.9848
# Epoch 9/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.1001 - acc: 0.9697 - val_loss: 0.0530 - val_acc: 0.9850
# Epoch 10/10
# 30596/30596 [==============================] - 2s 54us/step - loss: 0.0961 - acc: 0.9709 - val_loss: 0.0402 - val_acc: 0.9875

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Evaluate model
# - evaluate your model and get accuracy
# - use test features and labels

# %%
#print the the weights of the trained model
#for layer in model.layers:
#    weights = layer.get_weights()
#    print (weights)

# %%
# Final evaluation of the model
scores = model.evaluate(xtest4, ytest4, verbose=0)
print("scores: ", scores, " Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# scores:  [0.04023912507952953, 0.9875462152981577]  Baseline Error: 1.25%

# %%
#print the the weights of the trained model to compare it with future transfer model - if it is frozen
model.layers[0].get_weights()
# Out:
# [array([[[[-0.00343903, -0.00419648, -0.00268865,  0.04617973,
#            -0.11116771,  0.11864249,  0.06875863, -0.01183974,
#            -0.01916767, -0.03684183, -0.00770359, -0.04559299,
#            -0.12642632, -0.01203784,  0.08670217, -0.06425618,
#             0.04930879, -0.12251496, -0.12973006,  0.17204748,
#             0.01138286, -0.08576399,  0.15196738, -0.12824364,
#            -0.02134753, -0.05867773,  0.16486463,  0.1930874 ,
#            -0.13217558, -0.09676608, -0.13256182,  0.05730176]],
#
#          [[ 0.03885152,  0.16804644,  0.18723325,  0.09307155,
#            -0.10113068,  0.18837605, -0.12291124,  0.07579075,
#             0.05936085,  0.20744073, -0.06640424, -0.09501099,
#            -0.03341531, -0.01366433, -0.14231226, -0.14105298,
#            -0.08203762, -0.01381182, -0.08258277,  0.2777819 ,
#             0.09394912, -0.07915886,  0.16102698, -0.12830514,
#             0.20669848,  0.04437916,  0.14747679,  0.18537119,
#            -0.01258358, -0.08644042,  0.1188866 ,  0.15873507]],
#
#          [[-0.04868625,  0.05220113,  0.19454339,  0.05343736,
#            -0.00077345,  0.03221795, -0.02418466,  0.12624748,
#             0.23915379,  0.17854466,  0.06846035, -0.00542181,
#            -0.11855132, -0.0993104 , -0.02683551, -0.00151183,
#             0.0809343 , -0.13760926,  0.0722982 ,  0.2916666 ,
#            -0.13144295,  0.08427105,  0.10469445, -0.13692062,
#             0.22569175, -0.04143255,  0.15216662, -0.00668388,
#             0.06619499,  0.07486243,  0.05855199,  0.08612648]]],
#
#
#         [[[ 0.05669096, -0.09371487,  0.1317146 , -0.03276282,
#            -0.00153122,  0.10033557,  0.12778077,  0.03873243,
#             0.10135946,  0.1512839 , -0.00368832, -0.05266989,
#            -0.10343235, -0.02809823, -0.01064964,  0.10142077,
#            -0.11981068,  0.0398306 ,  0.09930557,  0.25693178,
#            -0.05159291,  0.02266938,  0.12640971,  0.0148929 ,
#             0.19707611, -0.00592658,  0.08291131,  0.1687407 ,
#             0.06133866,  0.0185296 , -0.0631127 ,  0.14286971]],
#
#          [[-0.03613404,  0.09846905,  0.2015421 , -0.10011257,
#             0.07514171,  0.19960253,  0.01493905,  0.10493039,
#             0.20710802,  0.20856023,  0.09780453, -0.08558348,
#             0.08962642, -0.04032008, -0.01132525,  0.09299713,
#            -0.00621138,  0.05283591,  0.00492336,  0.27557868,
#             0.08237106,  0.07924273,  0.01699175,  0.11835258,
#             0.11221307,  0.12892273,  0.08652048,  0.17147091,
#             0.09813616, -0.10008714,  0.07645573,  0.19550705]],
#
#          [[ 0.04939692,  0.15993229,  0.15930983, -0.13112341,
#            -0.06386197, -0.02041381],
#           ...,
#           [-0.04227773,  0.04920726, -0.0846427 , ..., -0.06184631,
#            -0.09396299,  0.00439093],
#           [ 0.05785138, -0.09652486, -0.00951566, ..., -0.0720516 ,
#             0.07294942,  0.06768285],
#           [-0.05493819,  0.07761875, -0.07223762, ..., -0.05085313,
#            -0.01945127,  0.07319049]],
#
#          [[-0.0672617 , -0.01643929,  0.04950656, ...,  0.0512338 ,
#            -0.04489857,  0.07335103],
#           [-0.08856109, -0.01363616,  0.06489892, ...,  0.10040595,
#            -0.09423582,  0.05873152],
#           [-0.00536074, -0.06160715, -0.01497408, ...,  0.05774897,
#            -0.02635147, -0.09239325],
#           ...,
#           [ 0.07145227,  0.08448011, -0.07013024, ..., -0.08940844,
#             0.02248181,  0.02159633],
#           [-0.03573495, -0.04620749,  0.00769482, ..., -0.03274605,
#             0.03939718,  0.02276573],
#           [-0.01432602,  0.01731353, -0.01118372, ...,  0.09827673,
#             0.09342291,  0.06328797]],
#
#          [[ 0.00358707,  0.09740118, -0.03486167, ..., -0.00972963,
#             0.01918466,  0.01951418],
#           [ 0.05534552, -0.0488351 , -0.00883147, ...,  0.00205022,
#            -0.05432801,  0.09238224],
#           [ 0.06322743,  0.13178478, -0.05738788, ..., -0.05719453,
#            -0.09859231,  0.09540821],
#           ...,
#           [ 0.02774347, -0.01921327,  0.08909244, ..., -0.06954969,
#             0.00199098,  0.01165069],
#           [-0.08134111,  0.04331945, -0.07374915, ..., -0.09911887,
#             0.02867315,  0.08668499],
#           [ 0.10358506,  0.01745065,  0.01980878, ..., -0.08006755,
#            -0.01947837,  0.09795206]]],
#
#
#         [[[-0.05287183,  0.03954545,  0.05892342, ..., -0.0390454 ,
#             0.02517701, -0.09278878],
#           [ 0.05553807,  0.00403926, -0.00403453, ...,  0.045751  ,
#            -0.05008004,  0.01395251],
#           [-0.07556503, -0.04664708, -0.07939965, ...,  0.05123781,
#             0.02769282,  0.0850978 ],
#           ...,
#           [-0.05792101, -0.0274566 , -0.07988904, ...,  0.10075656,
#            -0.07371742,  0.09572831],
#           [ 0.02077089,  0.07934476,  0.08247083, ..., -0.0995278 ,
#             0.08666904,  0.00665606],
#           [-0.0391484 ,  0.08079367,  0.09000712, ..., -0.04511093,
#            -0.04558116,  0.06673978]],
#
#          [[-0.05149594, -0.0443598 ,  0.08821444, ..., -0.06318814,
#             0.0616607 ,  0.0211585 ],
#           [ 0.01945879,  0.00433784,  0.02394056, ..., -0.0278829 ,
#             0.02490915,  0.00413814],
#           [ 0.08817858,  0.12805413, -0.04511141, ...,  0.02661402,
#             0.01184879,  0.05471636],
#           ...,
#           [ 0.05732085,  0.02321641,  0.02697102, ..., -0.06078241,
#             0.04512301,  0.09253824],
#           [-0.09735486, -0.08498669, -0.09155848, ..., -0.07967333,
#            -0.01541542,  0.03361271],
#           [-0.01965829,  0.07272477,  0.04086863, ..., -0.03375637,
#             0.0779508 , -0.03934262]],
#
#          [[ 0.06688664, -0.06930579,  0.0193262 , ..., -0.07726985,
#            -0.0842087 , -0.02829207],
#           [-0.03984879,  0.09421936, -0.04707005, ...,  0.01139812,
#             0.01483162,  0.01137722],
#           [ 0.1168268 , -0.01868658, -0.07044637, ..., -0.08900444,
#            -0.0701322 , -0.09850306],
#           ...,
#           [-0.05160405,  0.09976613,  0.07511966, ..., -0.07107089,
#             0.00595188,  0.0419655 ],
#           [ 0.0387993 , -0.00385712, -0.08128197, ...,  0.06798352,
#             0.08569049, -0.09081426],
#           [-0.07805814,  0.02680988, -0.00573112, ..., -0.03016378,
#            -0.04266347, -0.08830827]]],
#
#
#         [[[ 0.03149895,  0.08525512,  0.09663478, ..., -0.04249631,
#            -0.08322797, -0.00512291],
#           [ 0.03958781, -0.02409722, -0.0207006 , ...,  0.04974028,
#             0.07446387, -0.01207278],
#           [ 0.09473171,  0.06727525,  0.07734073, ..., -0.02042486,
#             0.07501343, -0.05283361],
#           ...,
#           [ 0.02647594, -0.03045744, -0.10021907, ..., -0.0646168 ,
#             0.0205591 , -0.03334926],
#           [ 0.07158055, -0.10081387,  0.04109104, ...,  0.01135077,
#            -0.03832522,  0.04812186],
#           [-0.06360828, -0.01265163,  0.10166247, ...,  0.00132164,
#             0.01927597, -0.06410866]],
#
#          [[ 0.0214978 ,  0.05022695, -0.03367883, ..., -0.03740445,
#            -0.07718764,  0.05973383],
#           [ 0.02390211,  0.00724951, -0.09472986, ..., -0.00276698,
#            -0.01041473, -0.03915539],
#           [ 0.01922632,  0.0380559 , -0.02668925, ...,  0.05281011,
#             0.02089813,  0.02657513],
#           ...,
#           [ 0.04078743,  0.01889347, -0.07075921, ...,  0.05323733,
#             0.057372  ,  0.01173329],
#           [-0.09017205, -0.05736936, -0.09946574, ..., -0.04310223,
#            -0.04723138, -0.09568158],
#           [ 0.10768986,  0.02140475, -0.03301048, ...,  0.10719583,
#             0.04805644,  0.06290492]],
#
#          [[ 0.04001487,  0.07200867,  0.03929719, ...,  0.01444412,
#             0.02999278,  0.03305047],
#           [ 0.05995686,  0.08475716, -0.08269804, ..., -0.01131765,
#             0.05362696,  0.07623213],
#           [-0.04872851,  0.04386694,  0.06495996, ...,  0.02669527,
#             0.09910043,  0.05645376],
#           ...,
#           [-0.0174051 , -0.05919452,  0.05331888, ...,  0.09408291,
#             0.05204768,  0.04891635],
#           [-0.05107678,  0.08363865,  0.08267988, ...,  0.04196552,
#             0.05778966,  0.0844597 ],
#           [ 0.05743587,  0.10024273, -0.01291123, ...,  0.08604567,
#             0.04302999, -0.08426572]]]], dtype=float32),
#  array([-0.01793838, -0.0241295 ,  0.0086948 ,  0.00024756,  0.01361604,
#         -0.01704318, -0.00966851,  0.0092382 ,  0.00391508,  0.00057479,
#         -0.01525262, -0.01444036,  0.00424755, -0.00410909, -0.00688116,
#          0.00238662, -0.02793538,  0.01326348, -0.01149923,  0.01051917,
#         -0.0007786 ,  0.01551857,  0.00731589,  0.02414913, -0.0180541 ,
#          0.00474504, -0.01002911, -0.00528657, -0.00569513, -0.00310017,
#          5.99950412e-03,  5.84237417e-03, -8.56499374e-03, -1.46219146e-03,
#          1.57002185e-03,  5.92918768e-05, -6.21133344e-03, -7.54400203e-03,
#          1.09350262e-03, -2.45399494e-03,  3.85989377e-04, -9.34523623e-03,
#          6.90134242e-03,  7.99018703e-03,  2.58521806e-03, -4.78974631e-04,
#         -6.62527600e-05,  1.01023763e-02,  9.42323729e-03,  1.76871847e-02],
#        dtype=float32)]

# %%
model.layers[7].get_weights()
# Out:
# [array([[ 0.01901741,  0.01976014, -0.21212122,  0.13429439,  0.04382906],
#         [ 0.19087058, -0.0938269 ,  0.15047798,  0.07477763, -0.17166434],
#         [-0.02087954,  0.09688562,  0.04374125,  0.07865987, -0.19075277],
#         [ 0.08568902, -0.11205011, -0.10056855,  0.17562501,  0.01507575],
#         [-0.04099394, -0.17789607,  0.05187426,  0.01166875,  0.00427114],
#         [ 0.03461408, -0.0146434 , -0.11430971,  0.00874566, -0.01184212],
#         [-0.15014847,  0.13060679, -0.02713819, -0.19897759,  0.12268341],
#         [ 0.16850445,  0.00245745,  0.10823058, -0.13166587,  0.04715113],
#         [-0.09583014,  0.21631683, -0.18756786, -0.11746496, -0.01883631],
#         [ 0.12169743, -0.02437982,  0.14477733,  0.16878851, -0.00680398],
#         [-0.02215991, -0.1693522 ,  0.12406862,  0.0550959 , -0.17701562],
#         [-0.19173168, -0.13709033,  0.18038249, -0.05943777,  0.19194521],
#         [-0.07506299, -0.15491493,  0.16090101,  0.12181213, -0.11655   ],
#         [-0.00493101,  0.21119191,  0.14249288, -0.12426001,  0.14750685],
#         [ 0.08495449,  0.22812887, -0.00516144,  0.22393976,  0.10880477],
#         [-0.05728725, -0.10041161, -0.22800523, -0.05203723, -0.02219381],
#         [-0.23320748,  0.23393545, -0.17060907, -0.07721891,  0.12314896],
#         [ 0.15746923, -0.12881422, -0.03462962,  0.08083067, -0.1361555 ],
#         [ 0.12540087, -0.06417254,  0.12583129,  0.04010137, -0.1661055 ],
#         [ 0.01078793, -0.17688084, -0.21121292,  0.17292893,  0.1617957 ],
#         [-0.12033405, -0.00402464,  0.20623992, -0.2182861 , -0.17039278],
#         [-0.19286378, -0.20586805, -0.03237658, -0.05268652,  0.01803355],
#         [-0.13850446, -0.19258232, -0.01005518,  0.05786494, -0.02092846],
#         [ 0.0074028 , -0.16267692, -0.00425915,  0.14517583, -0.19961832],
#         [-0.10707268,  0.11088803, -0.0237782 , -0.13368212,  0.04995421],
#         [ 0.13391787, -0.10945906,  0.02114004,  0.19437209,  0.12182176],
#         [ 0.02424885, -0.06076104, -0.02997915, -0.19854115,  0.17195286],
#         [-0.19487116, -0.14149809,  0.05603698,  0.18319051,  0.18415758],
#         [-0.08515591, -0.1836385 ,  0.12458624,  0.06058839, -0.12770735],
#         [ 0.19910227,  0.2714584 , -0.0460352 , -0.04285781,  0.13677493],
#         [-0.03062188,  0.23045556, -0.15342726,  0.19239561,  0.1671881 ],
#         [ 0.0435622 , -0.10946701, -0.08082538,  0.06532755, -0.13336839],
#         [-0.05932016,  0.20039244,  0.0557621 ,  0.16605136,  0.01381611],
#         [ 0.07796352,  0.15765949,  0.20561786, -0.03550542, -0.01837315],
#         [ 0.08917414, -0.00562746, -0.04774127,  0.24419293, -0.0181995 ],
#         [ 0.04446439,  0.06191507,  0.01993949,  0.15718247,  0.15252542],
#         [ 0.06577556, -0.18468554, -0.06052363, -0.2576296 , -0.00045552],
#         [ 0.15413265, -0.14146562,  0.15800211, -0.137515  ,  0.19215523],
#         [ 0.2141123 ,  0.00588155, -0.00596785,  0.1345809 ,  0.08443868],
#         [ 0.00878422, -0.20695877, -0.00118793,  0.0193323 , -0.24970005],
#         [ 0.00819974, -0.1168574 ,  0.03183232, -0.09411474, -0.05378356],
#         [ 0.14592978,  0.10901785, -0.13245477,  0.03749203, -0.19329824],
#         [ 0.15025902, -0.19956157,  0.04070655,  0.09202489, -0.05973541],
#         [ 0.00405002, -0.12910274,  0.12659252,  0.11463054, -0.23105597],
#         [ 0.1460722 ,  0.19875748, -0.05074656, -0.00187607, -0.06111632],
#         [-0.19046749, -0.01341043, -0.21713245, -0.21132366, -0.099268  ],
#         [-0.14799361, -0.00683457,  0.05196831,  0.01954794, -0.02807636],
#         [-0.15736164, -0.11375371,  0.14639854,  0.16473873,  0.18940796],
#         [ 0.02130806, -0.09165706,  0.03845091, -0.02626986,  0.19884847],
#         [ 0.01730495,  0.2206641 , -0.16578831,  0.19092081, -0.01327031],
#         [-0.05558757,  0.20459157,  0.15365501,  0.03450087, -0.21782859],
#         [-0.17305453,  0.20108835, -0.19677606, -0.12582864,  0.19748822]],
#        dtype=float32),
#  array([-0.03900851,  0.07315239,  0.01833958, -0.03011634, -0.02236723],
#        dtype=float32)]

# %% [markdown]
# ## Question 10

# %% [markdown]
# ## Transfer learning
# Now we will apply this model on second dataset (5-9 digits)
#
# - fix the first convolution layers so that the weights in the convolution layers dont get updated in the process of training
# - get the second dataset
# - train the last 2 dense layers
# - predict the accuracy and loss

# %% [markdown]
# ### Make only dense layers trainable
# - set trainalble = False for all layers other than Dense layers

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               589952
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 600,165
# Trainable params: 600,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Modify data
# - in your second data, class labels will start from 5 to 9 but for keras.utils.to_categorical the labels should start from 0
# - so you need to subtract 5 from train and test labels

# %%
ytrain9 = ytrain9 - 5
ytest9 = ytest9 - 5

# %%
ytest9
# Out:
# array([2, 4, 0, ..., 4, 0, 1], dtype=uint8)

# %%
ytrain9
# Out:
# array([0, 4, 0, ..., 0, 1, 3], dtype=uint8)

# %% [markdown]
# ### Reshape data
# - reshape second dataset
# - To be able to use the dataset in Keras, we need 4-dims numpy arrays.
# - reshape features to pass it to a Conv2D layer
# - channel = 1
# - reshape features of second dataset only
# - do not reshape labels

# %%
# Reshaping the array to 4-dims so that it can work with the Keras API
xtrain9 = X_train_5_9.reshape(xtrain9.shape[0], 28, 28, 1)
xtest9 = X_test_5_9.reshape(xtest9.shape[0], 28, 28, 1)

# %% [markdown]
# ### Normalize data
# - normalize second data
# - we must normalize our data as it is always required in neural network models
# - we can achieve this by dividing the RGB codes to 255 (which is the maximum RGB code minus the minimum RGB code)
# - normalize X_train and X_test
# - make sure that the values are float so that we can get decimal points after division

# %%
# Making sure that the values are float so that we can get decimal points after division
xtrain9 = xtrain9.astype('float32')
xtest9 = xtest9.astype('float32')
# Normalizing the RGB codes by dividing it to the max RGB value.
xtrain9 /= 255
xtest9 /= 255

# %% [markdown]
# ### Print shape of data and number of images
# - print shape of X_train
# - print number of images in X_train
# - print number of images in X_test

# %%
print('xtrain4:', xtrain4.shape)
print('ytrain4:', ytrain4.shape)
print('xtest4:', xtest4.shape)
print('ytest4:', ytest4.shape)
print('xtrain9:', xtrain9.shape)
print('ytrain9:', ytrain9.shape)
print('xtest9:', xtest9.shape)
print('ytest9:', ytest9.shape)
# Out:
# xtrain4: (30596, 28, 28, 1)
# ytrain4: (30596, 5)
# xtest4: (5139, 28, 28, 1)
# ytest4: (5139, 5)
# xtrain9: (29404, 28, 28, 1)
# ytrain9: (29404,)
# xtest9: (4861, 28, 28, 1)
# ytest9: (4861,)

# %% [markdown]
# ### One-hot encode the class vector
# - convert class vectors (integers) to binary class matrix
# - convert y_train and y_test
# - number of classes: 5
# - we are doing this to use categorical_crossentropy as loss
#
# Hint: you can use keras.utils.to_categorical

# %%
ytrain9 = keras.utils.to_categorical(ytrain9, num_classes)
ytest9 = keras.utils.to_categorical(ytest9, num_classes)

# %% [markdown]
# ### Fit the model
# - give train data - features and labels
# - batch size: 128
# - epochs: 10
# - give validation data - features and labels

# %%
#Set pre-trained model layers to not trainable
for layer in model.layers[:5]:
    layer.trainable = False

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(xtrain9, ytrain9, 
          batch_size=128, nb_epoch=10, verbose=1, validation_data=(xtest9, ytest9))
# Out:
# Train on 29404 samples, validate on 4861 samples
# Epoch 1/10
# 29404/29404 [==============================] - 1s 44us/step - loss: 0.5971 - acc: 0.7988 - val_loss: 0.2341 - val_acc: 0.9247
# Epoch 2/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.3171 - acc: 0.8970 - val_loss: 0.1738 - val_acc: 0.9453
# Epoch 3/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.2570 - acc: 0.9174 - val_loss: 0.1481 - val_acc: 0.9541
# Epoch 4/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.2303 - acc: 0.9268 - val_loss: 0.1326 - val_acc: 0.9595
# Epoch 5/10
# 29404/29404 [==============================] - 1s 38us/step - loss: 0.2120 - acc: 0.9321 - val_loss: 0.1235 - val_acc: 0.9611
# Epoch 6/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.1962 - acc: 0.9369 - val_loss: 0.1191 - val_acc: 0.9628
# Epoch 7/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.1846 - acc: 0.9415 - val_loss: 0.1111 - val_acc: 0.9640
# Epoch 8/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.1753 - acc: 0.9439 - val_loss: 0.1034 - val_acc: 0.9675
# Epoch 9/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.1713 - acc: 0.9456 - val_loss: 0.1022 - val_acc: 0.9665
# Epoch 10/10
# 29404/29404 [==============================] - 1s 36us/step - loss: 0.1654 - acc: 0.9469 - val_loss: 0.0966 - val_acc: 0.9689

# %% [markdown]
# ### Evaluate model
# - evaluate your model and get accuracy
# - use test features and labels

# %%
# Final evaluation of the model
scores = model.evaluate(xtest9, ytest9, verbose=0)
print("scores: ", scores, " Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# scores:  [0.09664294923272698, 0.9689364329676303]  Baseline Error: 3.11%

# %%
model.layers[0].get_weights()
# Out:
# [array([[[[-0.00343903, -0.00419648, -0.00268865,  0.04617973,
#            -0.11116771,  0.11864249,  0.06875863, -0.01183974,
#            -0.01916767, -0.03684183, -0.00770359, -0.04559299,
#            -0.12642632, -0.01203784,  0.08670217, -0.06425618,
#             0.04930879, -0.12251496, -0.12973006,  0.17204748,
#             0.01138286, -0.08576399,  0.15196738, -0.12824364,
#            -0.02134753, -0.05867773,  0.16486463,  0.1930874 ,
#            -0.13217558, -0.09676608, -0.13256182,  0.05730176]],
#
#          [[ 0.03885152,  0.16804644,  0.18723325,  0.09307155,
#            -0.10113068,  0.18837605, -0.12291124,  0.07579075,
#             0.05936085,  0.20744073, -0.06640424, -0.09501099,
#            -0.03341531, -0.01366433, -0.14231226, -0.14105298,
#            -0.08203762, -0.01381182, -0.08258277,  0.2777819 ,
#             0.09394912, -0.07915886,  0.16102698, -0.12830514,
#             0.20669848,  0.04437916,  0.14747679,  0.18537119,
#            -0.01258358, -0.08644042,  0.1188866 ,  0.15873507]],
#
#          [[-0.04868625,  0.05220113,  0.19454339,  0.05343736,
#            -0.00077345,  0.03221795, -0.02418466,  0.12624748,
#             0.23915379,  0.17854466,  0.06846035, -0.00542181,
#            -0.11855132, -0.0993104 , -0.02683551, -0.00151183,
#             0.0809343 , -0.13760926,  0.0722982 ,  0.2916666 ,
#            -0.13144295,  0.08427105,  0.10469445, -0.13692062,
#             0.22569175, -0.04143255,  0.15216662, -0.00668388,
#             0.06619499,  0.07486243,  0.05855199,  0.08612648]]],
#
#
#         [[[ 0.05669096, -0.09371487,  0.1317146 , -0.03276282,
#            -0.00153122,  0.10033557,  0.12778077,  0.03873243,
#             0.10135946,  0.1512839 , -0.00368832, -0.05266989,
#            -0.10343235, -0.02809823, -0.01064964,  0.10142077,
#            -0.11981068,  0.0398306 ,  0.09930557,  0.25693178,
#            -0.05159291,  0.02266938,  0.12640971,  0.0148929 ,
#             0.19707611, -0.00592658,  0.08291131,  0.1687407 ,
#             0.06133866,  0.0185296 , -0.0631127 ,  0.14286971]],
#
#          [[-0.03613404,  0.09846905,  0.2015421 , -0.10011257,
#             0.07514171,  0.19960253,  0.01493905,  0.10493039,
#             0.20710802,  0.20856023,  0.09780453, -0.08558348,
# %%
model.layers[1].get_weights()
# Out:
# [array([[[[ 0.05835082, -0.02132027,  0.0353698 , ..., -0.09369626,
#             0.01483783, -0.02490311],
#           [ 0.04642335, -0.05221223, -0.06334937, ...,  0.0278489 ,
#             0.04257137,  0.01535767],
#           [ 0.04371422,  0.10885966,  0.06177876, ...,  0.04197079,
#            -0.06386197, -0.02041381],
#           ...,
#           [-0.04227773,  0.04920726, -0.0846427 , ..., -0.06184631,
#            -0.09396299,  0.00439093],
#           [ 0.05785138, -0.09652486, -0.00951566, ..., -0.0720516 ,
#             0.07294942,  0.06768285],
#           [-0.05493819,  0.07761875, -0.07223762, ..., -0.05085313,
#            -0.01945127,  0.07319049]],
#
#          [[-0.0672617 , -0.01643929,  0.04950656, ...,  0.0512338 ,
#            -0.04489857,  0.07335103],
#           [-0.08856109, -0.01363616,  0.06489892, ...,  0.10040595,
#            -0.09423582,  0.05873152],
#           [-0.00536074, -0.06160715, -0.01497408, ...,  0.05774897,
#            -0.02635147, -0.09239325],
#           ...,
#           [ 0.07145227,  0.08448011, -0.07013024, ..., -0.08940844,
#             0.02248181,  0.02159633],
#           [-0.03573495, -0.04620749,  0.00769482, ..., -0.03274605,
#             0.03939718,  0.02276573],
#           [-0.01432602,  0.01731353, -0.01118372, ...,  0.09827673,
#             0.09342291,  0.06328797]],
#
#          [[ 0.00358707,  0.09740118, -0.03486167, ..., -0.00972963,
#             0.01918466,  0.01951418],
#           [ 0.05534552, -0.0488351 , -0.00883147, ...,  0.00205022,
#            -0.05432801,  0.09238224],
#           [ 0.06322743,  0.13178478, -0.05738788, ..., -0.05719453,
#            -0.09859231,  0.09540821],
#           ...,
#           [ 0.02774347, -0.01921327,  0.08909244, ..., -0.06954969,
#             0.00199098,  0.01165069],
#           [-0.08134111,  0.04331945, -0.07374915, ..., -0.09911887,
#             0.02867315,  0.08668499],
#           [ 0.10358506,  0.01745065,  0.01980878, ..., -0.08006755,
#            -0.01947837,  0.09795206]]],
#
#
#         [[[-0.05287183,  0.03954545,  0.05892342, ..., -0.0390454 ,
#             0.02517701, -0.09278878],
#           [ 0.05553807,  0.00403926, -0.00403453, ...,  0.045751  ,
#            -0.05008004,  0.01395251],
#           [-0.07556503, -0.04664708, -0.07939965, ...,  0.05123781,
#             0.02769282,  0.0850978 ],
#           ...,
#           [-0.05792101, -0.0274566 , -0.07988904, ...,  0.10075656,
#            -0.07371742,  0.09572831],
#           [ 0.02077089,  0.07934476,  0.08247083, ..., -0.0995278 ,
#             0.08666904,  0.00665606],
#           [-0.0391484 ,  0.08079367,  0.09000712, ..., -0.04511093,
#            -0.04558116,  0.06673978]],
#
#          [[-0.05149594, -0.0443598 ,  0.08821444, ..., -0.06318814,
#             0.0616607 ,  0.0211585 ],
#           [ 0.01945879,  0.00433784,  0.02394056, ..., -0.0278829 ,
#             0.02490915,  0.00413814],
#           [ 0.08817858,  0.12805413, -0.04511141, ...,  0.02661402,
#             0.01184879,  0.05471636],
#           ...,
#           [ 0.05732085,  0.02321641,  0.02697102, ..., -0.06078241,
#             0.04512301,  0.09253824],
#           [-0.09735486, -0.08498669, -0.09155848, ..., -0.07967333,
#            -0.01541542,  0.03361271],
#           [-0.01965829,  0.07272477,  0.04086863, ..., -0.03375637,
#             0.0779508 , -0.03934262]],
#
#          [[ 0.06688664, -0.06930579,  0.0193262 , ..., -0.07726985,
#            -0.0842087 , -0.02829207],
#           [-0.03984879,  0.09421936, -0.04707005, ...,  0.01139812,
#             0.01483162,  0.01137722],
#           [ 0.1168268 , -0.01868658, -0.07044637, ..., -0.08900444,
#            -0.0701322 , -0.09850306],
#           ...,
#           [-0.05160405,  0.09976613,  0.07511966, ..., -0.07107089,
#             0.00595188,  0.0419655 ],
#           [ 0.0387993 , -0.00385712, -0.08128197, ...,  0.06798352,
#             0.08569049, -0.09081426],
#           [-0.07805814,  0.02680988, -0.00573112, ..., -0.03016378,
#            -0.04266347, -0.08830827]]],
#
#
#         [[[ 0.03149895,  0.08525512,  0.09663478, ..., -0.04249631,
#            -0.08322797, -0.00512291],
#           [ 0.03958781, -0.02409722, -0.0207006 , ...,  0.04974028,
#             0.07446387, -0.01207278],
#           [ 0.09473171,  0.06727525,  0.07734073, ..., -0.02042486,
#             0.07501343, -0.05283361],
#           ...,
#           [ 0.02647594, -0.03045744, -0.10021907, ..., -0.0646168 ,
#             0.0205591 , -0.03334926],
#           [ 0.07158055, -0.10081387,  0.04109104, ...,  0.01135077,
#            -0.03832522,  0.04812186],
#           [-0.06360828, -0.01265163,  0.10166247, ...,  0.00132164,
#             0.01927597, -0.06410866]],
#
#          [[ 0.0214978 ,  0.05022695, -0.03367883, ..., -0.03740445,
#            -0.07718764,  0.05973383],
#           [ 0.02390211,  0.00724951, -0.09472986, ..., -0.00276698,
#            -0.01041473, -0.03915539],
#           [ 0.01922632,  0.0380559 , -0.02668925, ...,  0.05281011,
#             0.02089813,  0.02657513],
#           ...,
#           [ 0.04078743,  0.01889347, -0.07075921, ...,  0.05323733,
#             0.057372  ,  0.01173329],
#           [-0.09017205, -0.05736936, -0.09946574, ..., -0.04310223,
#            -0.04723138, -0.09568158],
#           [ 0.10768986,  0.02140475, -0.03301048, ...,  0.10719583,
#             0.04805644,  0.06290492]],
#
#          [[ 0.04001487,  0.07200867,  0.03929719, ...,  0.01444412,
#             0.02999278,  0.03305047],
#           [ 0.05995686,  0.08475716, -0.08269804, ..., -0.01131765,
#             0.05362696,  0.07623213],
#           [-0.04872851,  0.04386694,  0.06495996, ...,  0.02669527,
#             0.09910043,  0.05645376],
#           ...,
#           [-0.0174051 , -0.05919452,  0.05331888, ...,  0.09408291,
#             0.05204768,  0.04891635],
#           [-0.05107678,  0.08363865,  0.08267988, ...,  0.04196552,
#             0.05778966,  0.0844597 ],
#           [ 0.05743587,  0.10024273, -0.01291123, ...,  0.08604567,
#             0.04302999, -0.08426572]]]], dtype=float32),
#  array([-0.01793838, -0.0241295 ,  0.0086948 ,  0.00024756,  0.01361604,
#         -0.01704318, -0.00966851,  0.0092382 ,  0.00391508,  0.00057479,
#           3.45716290e-02, -2.17529193e-01],
#         [-1.73547655e-01,  1.99491471e-01, -1.93733275e-01,
#          -1.26005724e-01,  1.96712524e-01]], dtype=float32),
#  array([ 0.01967034,  0.08999455, -0.03604048, -0.03777713, -0.03584762],
#        dtype=float32)]

# %% [markdown]
# *The dense layers that were frozen did not change weight values in the newly trained model.
# But the not frozen layers weight got changed - As expected*

# %% [markdown]
# -----------------------------------------------------------------------------

# %% [markdown]
# # Sentiment analysis
#
# The objective of the second problem is to perform Sentiment analysis from the tweets collected from the users targeted at various mobile devices.
# Based on the tweet posted by a user (text), we will classify if the sentiment of the user targeted at a particular mobile device is positive or not.

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Read the data
# - read tweets.csv
# - use latin encoding if it gives encoding error while loading

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/tweets.csv',encoding ='latin1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Drop null values
# - drop all the rows with null values

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isna().values.any()
# Out:
# True

# %%
data = data.dropna()

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Print the dataframe
# - print initial 5 rows of the data
# - use df.head()

# %%
data.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...  ...                                   Negative emotion
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  ...                                   Positive emotion
# 2  @swonderlin Can not wait for #iPad 2 also. The...  ...                                   Positive emotion
# 3  @sxsw I hope this year's festival isn't as cra...  ...                                   Negative emotion
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Preprocess data
# - convert all text to lowercase - use .lower()
# - select only numbers, alphabets, and #+_ from text - use re.sub()
# - strip all the text - use .strip()
#     - this is for removing extra spaces

# %%
data['tweet_text'] = data['tweet_text'].str.lower()

# %% [markdown]
# print dataframe

# %%
data.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  .@wesley83 i have a 3g iphone. after 3 hrs twe...  ...                                   Negative emotion
# 1  @jessedee know about @fludapp ? awesome ipad/i...  ...                                   Positive emotion
# 2  @swonderlin can not wait for #ipad 2 also. the...  ...                                   Positive emotion
# 3  @sxsw i hope this year's festival isn't as cra...  ...                                   Negative emotion
# 4  @sxtxstate great stuff on fri #sxsw: marissa m...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %%
import re
data = data.applymap(lambda x: re.sub(r"[^0-9A-Za-z#+_ ]+","",x))
data.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                   Negative emotion
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                   Positive emotion
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                   Positive emotion
# 3  sxsw i hope this years festival isnt as crashy...  ...                                   Negative emotion
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %%
data.tweet_text = data.tweet_text.str.strip()
data.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                   Negative emotion
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                   Positive emotion
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                   Positive emotion
# 3  sxsw i hope this years festival isnt as crashy...  ...                                   Negative emotion
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Preprocess data
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - select only those rows where value equal to "positive emotion" or "negative emotion"
# - find the value counts of "positive emotion" and "negative emotion"

# %%
col = 'is_there_an_emotion_directed_at_a_brand_or_product'

# %%
data = data[(data[col] == 'Negative emotion') | (data[col] == 'Positive emotion')]

# %%
data.head
# Out:
# <bound method NDFrame.head of                                              tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0     wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                   Negative emotion
# 1     jessedee know about fludapp  awesome ipadiphon...  ...                                   Positive emotion
# 2     swonderlin can not wait for #ipad 2 also they ...  ...                                   Positive emotion
# 3     sxsw i hope this years festival isnt as crashy...  ...                                   Negative emotion
# 4     sxtxstate great stuff on fri #sxsw marissa may...  ...                                   Positive emotion
# 7     #sxsw is just starting #ctia is around the cor...  ...                                   Positive emotion
# 8     beautifully smart and simple idea rt madebyman...  ...                                   Positive emotion
# 9     counting down the days to #sxsw plus strong ca...  ...                                   Positive emotion
# 10    excited to meet the samsungmobileus at #sxsw s...  ...                                   Positive emotion
# 11    find amp start impromptu parties at #sxsw with...  ...                                   Positive emotion
# 12    foursquare ups the game just in time for #sxsw...  ...                                   Positive emotion
# 13    gotta love this #sxsw google calendar featurin...  ...                                   Positive emotion
# 14    great #sxsw ipad app from madebymany httptinyu...  ...                                   Positive emotion
# 15    haha awesomely rad ipad app by madebymany http...  ...                                   Positive emotion
# 17    i just noticed dst is coming this weekend how ...  ...                                   Negative emotion
# 18    just added my #sxsw flights to planely matchin...  ...                                   Positive emotion
# 19    must have #sxsw app rt malbonster lovely revie...  ...                                   Positive emotion
# 20    need to buy an ipad2 while im in austin at #sx...  ...                                   Positive emotion
# 21    oh my god the #sxsw app for ipad is pure unadu...  ...                                   Positive emotion
# 22    okay this is really it yay new foursquare for ...  ...                                   Positive emotion
# 23    photo just installed the #sxsw iphone app whic...  ...                                   Positive emotion
# 24    really enjoying the changes in gowalla 30 for ...  ...                                   Positive emotion
# 25    rt laurieshook im looking forward to the #smcd...  ...                                   Positive emotion
# 26    rt haha awesomely rad ipad app by madebymany h...  ...                                   Positive emotion
# 27    someone started an #austin partnerhub group in...  ...                                   Positive emotion
# 28    the new #4sq3 looks like it is going to rock u...  ...                                   Positive emotion
# 29    they were right the gowalla 3 app on #android ...  ...                                   Positive emotion
# 30    very smart from madebymany #hollergram ipad ap...  ...                                   Positive emotion
# 31    you must have this app for your ipad if you ar...  ...                                   Positive emotion
# 36    the best  rt mention ha first in line for #ipa...  ...                                   Positive emotion
# ...                                                 ...  ...                                                ...
# 9000  dropped my macbook pro as i was walking into #...  ...                                   Positive emotion
# 9006  creativity prompt use google maps to virtually...  ...                                   Positive emotion
# 9008  im pretty sure the panelist that thinks quotap...  ...                                   Negative emotion
# 9009  very happy that discovr has been named as one ...  ...                                   Positive emotion
# 9012  apparently there is an ipad and iphone app to ...  ...                                   Positive emotion
# 9013  on the way to #sxsw see you all tonight hopefu...  ...                                   Positive emotion
# 9017  stopped by tron legacy lounge at  #sxsw audio ...  ...                                   Positive emotion
# 9018  second day using my apple ipad2 at #sxsw and i...  ...                                   Positive emotion
# 9022  by the way i love that yall are so down to dis...  ...                                   Positive emotion
# 9025  absolutely  rt mention timely good schtuff fro...  ...                                   Positive emotion
# 9027  good job yall  rt mention yes gowalla wins bes...  ...                                   Positive emotion
# 9029  top story at #sxsw apple schools the marketing...  ...                                   Positive emotion
# 9033  mention yep i cant believe they set up a pop u...  ...                                   Positive emotion
# 9035  mention yes i picked up the ipad 2 at #sxsw my...  ...                                   Positive emotion
# 9036  mention yes thats why i favorited it i want to...  ...                                   Positive emotion
# 9044  look everyone zomg mention got an ipad 2 on th...  ...                                   Positive emotion
# 9045  mention you are my favorite thanks for coming ...  ...                                   Positive emotion
# 9048  mention you bet man kindle and apple for sure ...  ...                                   Positive emotion
# 9060  mention you might also appreciate new iphone a...  ...                                   Positive emotion
# 9061  mention you realize im still padless i just ga...  ...                                   Positive emotion
# 9063  mention you should get the ipad 2  to save you...  ...                                   Positive emotion
# 9064  mention you should see the line here at #sxsw ...  ...                                   Positive emotion
# 9070  you know youve made it to #sxsw when you see a...  ...                                   Positive emotion
# 9071  what are your essentials for #sxsw  mine pocke...  ...                                   Positive emotion
# 9072  mention your iphone 4 cases are rad and ready ...  ...                                   Positive emotion
# 9077  mention your pr guy just convinced me to switc...  ...                                   Positive emotion
# 9079  quotpapyrussort of like the ipadquot  nice lol...  ...                                   Positive emotion
# 9080  diller says google tv quotmight be run over by...  ...                                   Negative emotion
# 9085  ive always used camera+ for my iphone bc it ha...  ...                                   Positive emotion
# 9088                         ipad everywhere #sxsw link  ...                                   Positive emotion
#
# [3191 rows x 3 columns]>

# %%
data[col].value_counts()
# Out:
# Positive emotion    2672
# Negative emotion     519
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Encode labels
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - change "positive emotion" to 1
#     - change "negative emotion" to 0
# - use map function to replace values

# %%
def emotion_code(x):
  if x == 'Positive emotion':
    return 1
  else:
    return 0
  
data[col] = data[col].map(lambda x: emotion_code(x))

# %%
data.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                                  0
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                                  1
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                                  1
# 3  sxsw i hope this years festival isnt as crashy...  ...                                                  0
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                                  1
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Get feature and label
# - get column "tweet_text" as feature
# - get column "is_there_an_emotion_directed_at_a_brand_or_product" as label

# %%
X = data['tweet_text']
Y = data['is_there_an_emotion_directed_at_a_brand_or_product']

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
# %matplotlib inline

# split the the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=1, test_size=0.25)

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Vectorize data
# - create document-term matrix
# - use CountVectorizer()
#     - ngram_range: (1, 2)
#     - stop_words: 'english'
#     - min_df: 2
# - do fit_transform on X_train
# - do transform on X_test

# %%
# use CountVectorizer to create document-term matrices from X_train and X_test
vect = CountVectorizer(ngram_range = (1, 2), stop_words = 'english', min_df = 2)

# create document-term matrices
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
X_train_dtm.shape
# Out:
# (2393, 5434)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Select classifier logistic regression
# - use logistic regression for predicting sentiment of the given tweet
# - initialize classifier

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %% [markdown]
# ### Fit the classifer
# - fit logistic regression classifier

# %%
lr.fit(X_train_dtm, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Select classifier naive bayes
# - use naive bayes for predicting sentiment of the given tweet
# - initialize classifier
# - use MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()

# %% [markdown]
# ### Fit the classifer
# - fit naive bayes classifier

# %%
nb.fit(X_train_dtm, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Make predictions on logistic regression
# - use your trained logistic regression model to make predictions on X_test

# %%
y_lrpred_class = lr.predict(X_test_dtm)

# %% [markdown]
# ### Make predictions on naive bayes
# - use your trained naive bayes model to make predictions on X_test
# - use a different variable name to store predictions so that they are kept separately

# %%
y_nbpred_class = nb.predict(X_test_dtm)

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Calculate accuracy of logistic regression
# - check accuracy of logistic regression classifer
# - use sklearn.metrics.accuracy_score

# %%
print (metrics.accuracy_score(y_test, y_lrpred_class))
# Out:
# 0.8659147869674185

# %% [markdown]
# ### Calculate accuracy of naive bayes
# - check accuracy of naive bayes classifer
# - use sklearn.metrics.accuracy_score

# %%
print ('Accuracy: ', metrics.accuracy_score(y_test, y_nbpred_class))
# Out:
# Accuracy:  0.8571428571428571
